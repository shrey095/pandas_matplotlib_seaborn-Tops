# %% [markdown]
# ## Theoretical Assignments:

# %% [markdown]
# # Q1)Write an Essay: Importance of Data Cleaning in Data Science

# %% [markdown]
# **The Importance of Data Cleaning in Data Science**
#
# ### Introduction
# Data is the backbone of data science, and its quality significantly influences the accuracy and reliability of insights. Data cleaning, also known as data cleansing or data scrubbing, is the process of detecting and correcting errors, inconsistencies, and inaccuracies in datasets. This step is essential for ensuring that data is accurate, complete, and useful for analysis. Effective data cleaning leads to better decision-making, improved model performance, and more reliable business insights.
#
# ### Key Benefits of Data Cleaning
#
# #### 1. **Enhancing Data Quality**
#    - Removes duplicate entries, inconsistencies, and missing values.
#    - Ensures data is standardized and formatted correctly.
#    - Improves accuracy and completeness for better analysis.
#
# #### 2. **Improving Machine Learning Model Performance**
#    - Reduces bias and noise in data, leading to more precise predictions.
#    - Helps algorithms focus on meaningful patterns rather than erroneous data.
#    - Enhances training efficiency and reduces errors in model outputs.
#
# #### 3. **Reducing Processing Time and Costs**
#    - Prevents rework and troubleshooting due to poor data quality.
#    - Saves computational resources and reduces storage costs.
#    - Minimizes time spent cleaning data manually at later stages.
#
# #### 4. **Enhancing Decision-Making**
#    - Provides accurate and reliable insights for strategic planning.
#    - Ensures data-driven decisions are based on factual and complete information.
#    - Reduces risks associated with incorrect or misleading data.
#
# #### 5. **Ensuring Compliance and Security**
#    - Meets industry standards and regulatory requirements.
#    - Reduces risks related to data privacy and security breaches.
#    - Enhances trust in data usage, particularly in sensitive sectors like healthcare and finance.
#
# ### Conclusion
# Data cleaning is a critical step in the data science workflow that ensures accuracy, consistency, and reliability. By improving data quality, enhancing machine learning performance, reducing processing costs, supporting better decision-making, and ensuring compliance, data cleaning plays a vital role in the success of data-driven initiatives. Organizations must prioritize data cleaning to harness the full potential of their data and make impactful, data-driven decisions.

# %% [markdown]
# # 2)Presentation: Data Visualization Techniques & Best Practices

# %% [markdown]
# 🔹 Introduction
# Definition of Data Visualization
#
# Importance of Data Visualization in Data Science
#
# Key Objectives:
#
# Make complex data understandable
#
# Identify trends, patterns, and outliers
#
# Improve decision-making
#
# 🔹 Data Visualization Techniques
# 1️⃣ Charts & Graphs
# Bar Chart 📊 – Compare categorical data
#
# Line Chart 📈 – Show trends over time
#
# Pie Chart 🥧 – Display proportions (use sparingly)
#
# Scatter Plot 🔵 – Identify relationships between variables
#
# 2️⃣ Advanced Visualizations
# Histogram – Analyze frequency distribution
#
# Box Plot (Whisker Plot) – Show data distribution & outliers
#
# Heatmap – Represent correlation using color intensity
#
# TreeMap – Visualize hierarchical data
#
# 3️⃣ Geospatial Visualizations
# Choropleth Map – Show values over geographic areas
#
# Scatter Maps – Display data points on a map
#
# 🔹 Best Practices for Effective Data Visualization
# ✔️ Choosing the Right Chart
# Comparisons? → Use bar charts
#
# Trends over time? → Use line charts
#
# Proportions? → Use pie charts (limit slices < 6)
#
# Relationships? → Use scatter plots
#
# ✔️ Simplicity & Clarity
# Avoid clutter & unnecessary 3D effects
#
# Use clear labels and legends
#
# Keep color schemes intuitive
#
# ✔️ Color Usage
# Use consistent and meaningful colors
#
# Avoid excessive colors that confuse the audience
#
# Use contrast for better readability
#
# ✔️ Avoid Misleading Visuals
# Always start the Y-axis at zero (except in special cases)
#
# Avoid distorted scales and exaggerated proportions
#
# ✔️ Interactivity & Tools
# Use Dashboards for real-time insights
#
# Tools: Matplotlib, Seaborn, Power BI, Tableau, Plotly

# %% [markdown]
# ## Practical Tasks:

# %% [markdown]
# ###  Task 1: Importing Data from CSV, APIs, and Databases

# %% [markdown]
# #### Write Python scripts to: Connect Python to MySQL/PostgreSQL and fetch records.

# %%
import pandas as pd
import pymysql

# host,user,password,database name was changed
connection = pymysql.connect(
    host="localhostss",
    user="abcd",
    password="12345",
    database="hr"
)
try:
    with connection.cursor() as cursor:
        query = "SELECT * FROM departments"  
        cursor.execute(query)
        
        records = cursor.fetchall()
        
        for row in records:
            print(row)
finally:
    connection.close()
# Out:
# (10, 'Administration', 200, 1700)
# (20, 'Marketing', 201, 1800)
# (30, 'Purchasing', 114, 1700)
# (40, 'Human Resources', 203, 2400)
# (50, 'Shipping', 121, 1500)
# (60, 'IT', 103, 1400)
# (70, 'Public Relations', 204, 2700)
# (80, 'Sales', 145, 2500)
# (90, 'Executive', 100, 1700)
# (100, 'Finance', 108, 1700)
# (110, 'Accounting', 205, 1700)
# (120, 'Treasury', None, 1700)
# (130, 'Corporate Tax', None, 1700)
# (140, 'Control And Credit', None, 1700)
# (150, 'Shareholder Services', None, 1700)
# (160, 'Benefits', None, 1700)
# (170, 'Manufacturing', None, 1700)
# (180, 'Construction', None, 1700)
# (190, 'Contracting', None, 1700)
# (200, 'Operations', None, 1700)
# (210, 'IT Support', None, 1700)
# (220, 'NOC', None, 1700)
# (230, 'IT Helpdesk', None, 1700)
# (240, 'Government Sales', None, 1700)
# (250, 'Retail Sales', None, 1700)
# (260, 'Recruiting', None, 1700)
# (270, 'Payroll', None, 1700)

# %% [markdown]
# #### Read a CSV file using pandas.

# %%
df = pd.read_csv(r"E:\topsnots\banklist.csv")  
df
# print(df.head())
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %% [markdown]
# #### Retrieve data from an API (e.g., weather API)

# %%
import requests

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv" 
c = pd.read_csv(url)
c
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ### Task 2: Data Cleaning & Handling Missing Data

# %% [markdown]
# #### Use Pandas to:
# #### Identify missing values. Fill missing values with mean/median. Drop irrelevant columns.

# %%
data = {
    'ID': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', None, 'Eve'],
    'Age': [25, 30, None, 35, 40],
    'Salary': [50000, None, 70000, 80000, 90000],
    'Gender': ['F', 'M', 'M', 'F', 'F']
}
df = pd.DataFrame(data)
print("Missing Values:\n", df.isnull().sum())

df['Age'] = df['Age'].fillna(df['Age'].mean())  
df['Salary'] = df['Salary'].fillna(df['Salary'].median()) 

df = df.drop(columns=['ID'])
print("\nCleaned DataFrame:\n", df)
# Out:
# Missing Values:
#  ID        0
# Name      1
# Age       1
# Salary    1
# Gender    0
# dtype: int64
#
# Cleaned DataFrame:
#        Name   Age   Salary Gender
# 0    Alice  25.0  50000.0      F
# 1      Bob  30.0  75000.0      M
# 2  Charlie  32.5  70000.0      M
# 3     None  35.0  80000.0      F
# 4      Eve  40.0  90000.0      F

# %% [markdown]
# #### Task 3: Data Visualization (Matplotlib & Seaborn)  Load a dataset and create:
# Histogram for numerical data distribution.
# Scatter plot to show correlations.
# Heatmap of correlation matrix.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("titanic")
plt.figure(figsize=(13, 5))
sns.histplot(df['age'].dropna(), bins=20, kde=True, color="red")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df['age'], y=df['fare'], hue=df['sex'], alpha=0.6,palette={"male": "blue", "female": "purple"})
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Sex")
plt.show()

# %%
plt.figure(figsize=(8, 5))
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
